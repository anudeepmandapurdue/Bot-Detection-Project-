# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/talkingdata-adtracking-fraud-detection/train.csv')

# %%
print(df['is_attributed'].value_counts(normalize=False))
# Out:
# is_attributed
# 0    184447044
# 1       456846
# Name: count, dtype: int64
